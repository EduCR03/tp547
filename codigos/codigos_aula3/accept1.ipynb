# %% [markdown]
# <a href="https://colab.research.google.com/github/sam02/tp547/blob/main/codigos/codigos_aula3/accept1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

n=1000000
xfunction=np.array([])

for i in range(n):
    x1=np.random.uniform(0,1) # Valor aleatorio dentro da distribuicao
    x2=np.random.uniform(0,1) # Valor independente de y (x1), tbm aleatorio

    while (x2 >=(256/27)*x1*pow((1-x1),3)): # Expressao calculada, c g(x)
        x1=np.random.uniform(0,1)
        x2=np.random.uniform(0,1)
    xfunction = np.append(xfunction, x1)

print(xfunction)
X=np.arange(0, 1, 0.1)
fx=20*X*pow((1-X),3)
plt.plot(X,fx)
plt.hist(xfunction,bins=100,density=True)
plt.show()
# Out:
# [0.23624869 0.07149211 0.35736853 ... 0.22508226 0.29231212 0.41648157]
