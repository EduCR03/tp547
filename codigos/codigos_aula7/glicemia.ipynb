# %%
# !pip install numpy
# !pip install scipy
# Out:
# Requirement already satisfied: numpy in c:\users\eduar\appdata\local\programs\python\python310\lib\site-packages (2.1.3)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: C:\Users\eduar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\eduar\appdata\local\programs\python\python310\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\eduar\appdata\local\programs\python\python310\lib\site-packages (from scipy) (2.1.3)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: C:\Users\eduar\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import scipy.stats as sci
N=25
alpha=0.05
Glicemia=np.array([80,118,100,90,83,117,95,84,102,80,112,78,102,121,82,77,88,73,104,88,132,91,103,140,101])
media=np.mean(Glicemia)
print("A média amostral e", media)
desvio=np.sqrt(np.var(Glicemia))
print("O desvio padrão  amostral e",desvio)
limite=sci.t.ppf(1-alpha/2, N-1)
print(limite)
me= limite*desvio*np.sqrt(1/N) ;
CI95_lower=media-me;
CI95_upper=media+me;
print("O valor do intervalo inferior e",CI95_lower)
print("O valor do intervalo superior e",CI95_upper)
# Out:
# A média amostral e 97.64
# O desvio padrão  amostral e 17.460538365124943
# 2.0638985616280205
# O valor do intervalo inferior e 90.43264399659355
# O valor do intervalo superior e 104.84735600340645
